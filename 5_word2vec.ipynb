# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = {}
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = []
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From C:\Users\padmaraj.bhat\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\padmaraj.bhat\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:1444: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Users\padmaraj.bhat\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.844903
# Nearest to is: virtue, parkinson, galeon, knowing, scooter, deacon, sauces, functionalists,
# Nearest to who: combatants, wailing, xxvii, rarest, malvinas, smoothed, tarzan, specialises,
# Nearest to called: renewable, straw, variant, bray, promptly, turbofan, lighthearted, fripp,
# Nearest to he: switzerland, bhfuil, groupe, severly, tiers, kingfisher, personas, deterred,
# Nearest to often: prey, appeasement, piccadilly, carol, blocks, mhz, delete, dur,
# Nearest to at: estimator, clicked, cryogenics, teh, motor, kpd, wickedness, framing,
# Nearest to first: pesticide, briton, gpl, falcone, angelica, witold, johansson, heresiologists,
# Nearest to most: prototypes, barrelled, yersinia, teutonic, zx, tuireadh, hopf, lac,
# Nearest to they: multiverse, curium, armada, convincingly, burg, unrepentant, eckhart, cells,
# Nearest to more: rajonas, commemorating, pseudoscience, agrippa, pf, historians, mali, widehat,
# Nearest to two: labs, uncovering, scope, torr, ladakh, foreshadow, kimono, hyped,
# Nearest to states: melilla, alleged, snyder, lecturer, leda, nerve, morehouse, delicacy,
# Nearest to d: kerk, torrey, stiles, summary, pluralist, upu, fitzgerald, brink,
# Nearest to from: halal, disappointment, reeve, tradition, reintroduce, belli, candela, tenggara,
# Nearest to his: placement, mbe, putsch, puritanical, factional, forecasting, abundant, gide,
# Nearest to three: vaughan, rivers, convertible, howe, ramone, perpignan, sized, glasgow,
# Average loss at step 2000: 4.369871
# Average loss at step 4000: 3.864204
# Average loss at step 6000: 3.791162
# Average loss at step 8000: 3.688480
# Average loss at step 10000: 3.617087
# Nearest to is: was, are, has, be, galeon, kornilov, pathological, can,
# Nearest to who: he, precaution, combatants, and, feb, which, it, sheikh,
# Nearest to called: promptly, bray, riefenstahl, tights, researched, fripp, comerica, prut,
# Nearest to he: it, she, they, who, switzerland, throws, kingfisher, zoe,
# Nearest to often: also, mhz, prey, no, dating, darling, prominent, they,
# Nearest to at: estimator, on, in, motor, persisting, grbac, from, by,
# Nearest to first: same, heresiologists, recommendation, nasional, interned, pregnancy, briton, spacecraft,
# Nearest to most: vanderbilt, zx, performers, yersinia, teutonic, enthusiastic, gift, melding,
# Nearest to they: he, it, alford, radios, we, there, eastbound, shalt,
# Nearest to more: safeguard, uniform, pseudoscience, entendre, traditionally, transverse, rajonas, less,
# Nearest to two: three, five, four, six, seven, eight, nine, zero,
# Nearest to states: begging, vitrification, melilla, beaten, archduke, arguments, nerve, regrets,
# Nearest to d: bnetd, clu, fullest, byte, upu, kerk, brink, purchases,
# Nearest to from: in, by, with, demise, at, during, of, pis,
# Nearest to his: her, the, their, s, its, government, murders, cartographic,
# Nearest to three: four, six, five, two, eight, seven, zero, nine,
# Average loss at step 12000: 3.605653
# Average loss at step 14000: 3.574291
# Average loss at step 16000: 3.406494
# Average loss at step 18000: 3.460223
# Average loss at step 20000: 3.542082
# Nearest to is: was, are, has, powerful, be, but, were, pathological,
# Nearest to who: he, which, they, never, ottonian, often, precaution, have,
# Nearest to called: researched, bray, comerica, promptly, known, dyes, wicca, prut,
# Nearest to he: it, she, they, who, there, throws, originally, this,
# Nearest to often: also, sometimes, usually, generally, who, julmust, dating, suprarenal,
# Nearest to at: in, during, on, from, estimator, ideology, ohrid, under,
# Nearest to first: last, second, same, following, mariah, spacecraft, heresiologists, zuid,
# Nearest to most: more, vanderbilt, performers, zx, gift, many, diameter, exchanges,
# Nearest to they: he, we, there, it, alford, who, she, shalt,
# Nearest to more: less, most, uniform, safeguard, traditionally, transverse, entendre, pseudoscience,
# Nearest to two: three, five, four, seven, six, eight, zero, one,
# Nearest to states: begging, melilla, archduke, vitrification, fastened, us, autodidacts, favorite,
# Nearest to d: b, american, frisia, blond, fullest, microeconomic, italian, northernmost,
# Nearest to from: in, through, between, at, after, by, with, acc,
# Nearest to his: her, their, its, my, the, aquarists, murders, groundbreaking,
# Nearest to three: four, two, seven, five, six, eight, zero, nine,
# Average loss at step 22000: 3.502710
# Average loss at step 24000: 3.491706
# Average loss at step 26000: 3.483281
# Average loss at step 28000: 3.479475
# Average loss at step 30000: 3.502578
# Nearest to is: was, has, are, be, does, tray, were, had,
# Nearest to who: he, they, which, never, she, actually, it, bloemfontein,
# Nearest to called: researched, used, known, promptly, natasha, bray, welding, comerica,
# Nearest to he: it, she, they, who, there, originally, we, ze,
# Nearest to often: generally, sometimes, usually, also, commonly, frequently, now, typically,
# Nearest to at: in, on, during, until, under, forti, persisting, roaming,
# Nearest to first: last, second, market, recur, same, dakuten, clearwater, armory,
# Nearest to most: more, many, some, zx, performers, gift, exchanges, vanderbilt,
# Nearest to they: we, he, there, it, who, not, she, these,
# Nearest to more: less, most, uniform, turpentine, very, polluting, mez, principally,
# Nearest to two: four, one, five, three, seven, eight, six, zero,
# Nearest to states: begging, fastened, archduke, kingdom, vitrification, melilla, beaten, seminal,
# Nearest to d: b, bnetd, clu, microeconomic, meters, northernmost, ski, indie,
# Nearest to from: into, between, after, through, in, before, by, moynihan,
# Nearest to his: her, their, its, the, my, s, aquarists, our,
# Nearest to three: four, five, eight, six, seven, nine, zero, two,
# Average loss at step 32000: 3.502131
# Average loss at step 34000: 3.490891
# Average loss at step 36000: 3.455679
# Average loss at step 38000: 3.306608
# Average loss at step 40000: 3.426630
# Nearest to is: was, are, has, deluxe, flores, does, be, while,
# Nearest to who: which, he, often, they, that, she, never, microvision,
# Nearest to called: natasha, researched, used, sizable, eos, bray, known, comerica,
# Nearest to he: she, it, they, there, who, originally, i, we,
# Nearest to often: usually, generally, also, sometimes, commonly, typically, frequently, now,
# Nearest to at: on, during, in, grammarians, estimator, denounced, shahanshah, sceptre,
# Nearest to first: second, last, next, fourth, market, knot, fifth, provincias,
# Nearest to most: more, some, many, less, marks, goddess, gift, coloured,
# Nearest to they: we, he, there, you, it, she, not, these,
# Nearest to more: less, most, very, uniform, rather, turpentine, riff, safeguard,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to states: kingdom, begging, countries, vitrification, fastened, melilla, autodidacts, archduke,
# Nearest to d: b, bnetd, bryce, metamorphosis, UNK, yoshi, c, w,
# Nearest to from: through, into, between, in, dearborn, of, moynihan, automation,
# Nearest to his: her, their, its, my, the, s, aquarists, groundbreaking,
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Average loss at step 42000: 3.439921
# Average loss at step 44000: 3.453095
# Average loss at step 46000: 3.450383
# Average loss at step 48000: 3.353278
# Average loss at step 50000: 3.383943
# Nearest to is: was, are, has, contains, became, remains, verdicts, orl,
# Nearest to who: he, which, she, often, they, that, never, newborn,
# Nearest to called: natasha, known, used, wicca, eos, named, automator, leftmost,
# Nearest to he: she, it, they, there, who, i, mutant, we,
# Nearest to often: generally, usually, sometimes, commonly, also, now, frequently, typically,
# Nearest to at: on, during, against, in, benedictines, hinterland, toothed, grammarians,
# Nearest to first: second, last, next, fourth, facing, original, final, fifth,
# Nearest to most: more, some, many, use, less, performers, several, marks,
# Nearest to they: he, we, there, she, you, it, not, who,
# Nearest to more: less, most, very, too, uniform, quite, rather, turpentine,
# Nearest to two: three, four, six, five, one, eight, seven, nine,
# Nearest to states: kingdom, begging, vitrification, melilla, autodidacts, fastened, citizenry, tabloids,
# Nearest to d: b, bnetd, m, c, bryce, e, yoshi, p,
# Nearest to from: through, in, into, between, during, vehemently, gry, moynihan,
# Nearest to his: her, their, its, my, the, our, groundbreaking, whose,
# Nearest to three: four, six, seven, eight, five, two, nine, zero,
# Average loss at step 52000: 3.437601
# Average loss at step 54000: 3.430741
# Average loss at step 56000: 3.440468
# Average loss at step 58000: 3.393559
# Average loss at step 60000: 3.396045
# Nearest to is: was, are, has, although, remains, triglycerides, contains, be,
# Nearest to who: he, she, which, never, microvision, eph, but, that,
# Nearest to called: used, natasha, known, named, wicca, referred, automator, leftmost,
# Nearest to he: she, it, they, there, who, ze, eventually, originally,
# Nearest to often: usually, sometimes, generally, commonly, now, frequently, also, typically,
# Nearest to at: during, in, sceptre, fades, faramir, buyers, mutant, wikibook,
# Nearest to first: second, last, next, same, fourth, third, original, fifth,
# Nearest to most: many, more, some, use, performers, less, consist, eurovision,
# Nearest to they: we, there, you, he, she, it, i, not,
# Nearest to more: less, most, rather, very, increasingly, larger, too, uniform,
# Nearest to two: three, four, five, seven, six, one, eight, zero,
# Nearest to states: kingdom, countries, nations, vitrification, areas, begging, parliament, communities,
# Nearest to d: b, h, w, c, m, bnetd, t, bechtel,
# Nearest to from: through, into, in, vehemently, between, haughty, moynihan, dearborn,
# Nearest to his: her, their, its, my, the, whose, aquarists, our,
# Nearest to three: five, four, six, seven, eight, two, nine, zero,
# Average loss at step 62000: 3.240265
# Average loss at step 64000: 3.253882
# Average loss at step 66000: 3.403952
# Average loss at step 68000: 3.400514
# Average loss at step 70000: 3.361571
# Nearest to is: was, has, are, be, although, contains, does, makes,
# Nearest to who: he, she, which, microvision, often, never, subtleties, newborn,
# Nearest to called: natasha, known, named, referred, automator, used, wicca, bastiat,
# Nearest to he: she, it, they, there, who, eventually, originally, ze,
# Nearest to often: usually, sometimes, generally, commonly, frequently, now, also, typically,
# Nearest to at: during, on, within, wikibook, forti, mutant, after, faramir,
# Nearest to first: second, last, next, fourth, same, third, original, best,
# Nearest to most: more, many, some, less, use, eurovision, several, very,
# Nearest to they: we, there, he, you, she, it, eventually, i,
# Nearest to more: less, most, very, too, larger, quite, rather, greater,
# Nearest to two: three, four, six, seven, five, one, eight, zero,
# Nearest to states: kingdom, countries, nations, govt, vitrification, communities, fastened, state,
# Nearest to d: b, h, n, g, signifier, cantonese, smash, clu,
# Nearest to from: through, into, in, between, automation, moynihan, across, vehemently,
# Nearest to his: her, their, my, its, our, the, aquarists, whose,
# Nearest to three: two, four, five, six, seven, eight, nine, zero,
# Average loss at step 72000: 3.369505
# Average loss at step 74000: 3.348947
# Average loss at step 76000: 3.316186
# Average loss at step 78000: 3.352978
# Average loss at step 80000: 3.382457
# Nearest to is: was, has, are, contains, remains, although, became, be,
# Nearest to who: he, she, never, which, often, actually, subtleties, microvision,
# Nearest to called: known, used, named, natasha, referred, automator, bastiat, leftmost,
# Nearest to he: she, it, they, there, who, we, eventually, this,
# Nearest to often: usually, sometimes, generally, commonly, typically, frequently, now, still,
# Nearest to at: in, wikibook, during, on, stillman, after, unmatched, shaky,
# Nearest to first: second, last, third, next, fourth, best, same, final,
# Nearest to most: more, less, many, some, performers, consist, eurovision, emphasizes,
# Nearest to they: we, he, you, there, she, it, these, however,
# Nearest to more: less, most, very, quite, larger, too, rather, principally,
# Nearest to two: three, six, four, five, seven, one, eight, zero,
# Nearest to states: kingdom, nations, countries, state, tabloids, us, arab, vitrification,
# Nearest to d: b, h, f, e, dimensions, ruhr, indie, paschal,
# Nearest to from: through, into, before, during, after, in, across, moynihan,
# Nearest to his: her, their, my, its, our, the, your, ingestion,
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Average loss at step 82000: 3.407008
# Average loss at step 84000: 3.413359
# Average loss at step 86000: 3.387863
# Average loss at step 88000: 3.350865
# Average loss at step 90000: 3.364701
# Nearest to is: was, has, are, contains, although, be, makes, remains,
# Nearest to who: he, actually, which, she, never, eph, often, but,
# Nearest to called: referred, named, known, used, natasha, adrenaline, termed, leftmost,
# Nearest to he: she, they, it, there, who, originally, we, but,
# Nearest to often: usually, sometimes, generally, commonly, frequently, typically, now, also,
# Nearest to at: during, on, under, shaky, fgth, praetorians, forti, in,
# Nearest to first: second, last, original, next, final, third, best, same,
# Nearest to most: more, some, less, many, performers, particularly, eurovision, iconography,
# Nearest to they: we, he, you, there, she, it, but, not,
# Nearest to more: less, most, very, quite, greater, too, larger, rather,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to states: kingdom, nations, state, countries, us, arab, governments, areas,
# Nearest to d: b, ruhr, dimensions, measles, transhumanism, plight, h, stiles,
# Nearest to from: through, into, moynihan, during, before, in, across, between,
# Nearest to his: her, their, its, my, our, your, s, the,
# Nearest to three: four, two, five, eight, seven, six, nine, zero,
# Average loss at step 92000: 3.401805
# Average loss at step 94000: 3.258175
# Average loss at step 96000: 3.362241
# Average loss at step 98000: 3.246168
# Average loss at step 100000: 3.353029
# Nearest to is: was, has, are, became, refers, be, contains, when,
# Nearest to who: he, she, never, which, usually, actually, microvision, often,
# Nearest to called: named, referred, known, natasha, adrenaline, campo, termed, leftmost,
# Nearest to he: she, it, they, there, we, who, never, this,
# Nearest to often: usually, sometimes, generally, commonly, frequently, typically, actually, now,
# Nearest to at: during, in, on, shahanshah, with, after, sceptre, forti,
# Nearest to first: last, second, next, fourth, third, final, best, original,
# Nearest to most: more, less, some, many, performers, eurovision, among, particularly,
# Nearest to they: we, he, there, you, she, it, grupo, i,
# Nearest to more: less, most, very, quite, larger, greater, extremely, rather,
# Nearest to two: four, three, five, six, seven, eight, one, zero,
# Nearest to states: kingdom, nations, countries, state, arab, us, totaling, fastened,
# Nearest to d: b, indie, transhumanism, baudelaire, c, quintessence, h, beazley,
# Nearest to from: through, into, between, during, gry, moynihan, across, bowen,
# Nearest to his: her, their, its, my, our, your, the, s,
# Nearest to three: five, four, six, seven, eight, two, nine, zero,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, 1, 1)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.815268
# Nearest to is: basenji, unsuitable, wff, hallucinogenic, manufactures, chirality, amylase, fifties,
# Nearest to who: curtail, hawkins, gale, misleading, infertile, smashing, feminine, pnp,
# Nearest to called: casualty, prefers, feign, atheist, packets, thermopylae, transcendence, shreck,
# Nearest to he: refund, synthetic, quartet, glossolalia, scalp, cuttlefish, anglican, meribbaal,
# Nearest to often: royal, doherty, flatland, obadiah, auguste, kremlin, shapeshifting, hatred,
# Nearest to at: incompressible, comedy, phosphide, hyperinsulinism, charged, classify, fistula, indira,
# Nearest to first: scoping, diddy, bm, bronson, expects, kerouac, saa, eros,
# Nearest to most: weddings, nonprofit, peterborough, connolly, melanchthon, gotlanders, overseer, kicking,
# Nearest to they: nssdc, mothman, textual, schr, hectic, tendons, genitalia, descriptions,
# Nearest to more: steroid, younger, luke, akc, zuma, bigfoot, transcription, loot,
# Nearest to two: innumerable, thermal, novell, kenya, wrc, neurotransmitter, carburetor, jesu,
# Nearest to states: callers, portraits, pixels, porte, limits, pyramid, academic, wynette,
# Nearest to d: blocker, mongols, verdict, frozen, progenitors, seaport, suggestive, wenzel,
# Nearest to from: glaucus, reciprocity, upstairs, ancestries, deport, lore, ammianus, alvarado,
# Nearest to his: spl, scripting, ralf, quijote, universit, fusion, nesmith, wilhelmshaven,
# Nearest to three: evict, herold, sixteen, vesque, instrument, marianas, painter, imams,
# Average loss at step 2000: 4.450244
# Average loss at step 4000: 3.990373
# Average loss at step 6000: 3.808353
# Average loss at step 8000: 3.772997
# Average loss at step 10000: 3.733267
# Nearest to is: was, are, has, be, were, had, as, maxine,
# Nearest to who: he, totaled, never, they, also, and, which, magni,
# Nearest to called: austral, hunnish, packets, dipping, worthless, mitochondria, discogs, ebenezer,
# Nearest to he: it, she, they, who, lagi, filler, mughals, synthetic,
# Nearest to often: also, it, cris, quadrant, still, shipping, dogged, tubes,
# Nearest to at: in, on, cuckoo, for, encodings, jazzy, after, to,
# Nearest to first: kerouac, harriers, actual, last, unwieldy, venlo, redirect, bm,
# Nearest to most: nonprofit, lured, longfellow, melanchthon, cranial, principles, while, pips,
# Nearest to they: there, he, not, cretan, you, it, disregards, we,
# Nearest to more: midas, schlick, younger, owns, radiocommunication, chronicon, deuteronomy, if,
# Nearest to two: three, four, one, five, six, eight, seven, nine,
# Nearest to states: callers, pixels, limits, koch, aquino, eva, slashing, chained,
# Nearest to d: UNK, blocker, e, blas, camino, gomorrah, specificity, aw,
# Nearest to from: in, codeine, among, by, and, ahaziah, under, of,
# Nearest to his: its, their, her, the, s, legacy, this, curls,
# Nearest to three: four, two, five, seven, six, one, eight, nine,
# Average loss at step 12000: 3.676415
# Average loss at step 14000: 3.601041
# Average loss at step 16000: 3.594391
# Average loss at step 18000: 3.539213
# Average loss at step 20000: 3.614353
# Nearest to is: was, are, has, be, does, became, munich, if,
# Nearest to who: he, totaled, they, which, never, stumble, wilmot, also,
# Nearest to called: hunnish, packets, abba, austral, dipping, illyria, borzois, chobert,
# Nearest to he: she, it, they, who, there, filler, lagi, hinders,
# Nearest to often: also, quadrant, still, cris, sometimes, tubes, it, generally,
# Nearest to at: in, nye, incompressible, for, on, nauvoo, over, southeast,
# Nearest to first: last, second, same, best, harriers, kerouac, third, aliases,
# Nearest to most: principles, more, longfellow, nonprofit, gilgamesh, cranial, steelers, lured,
# Nearest to they: we, he, there, you, it, who, not, cretan,
# Nearest to more: most, less, younger, radiocommunication, too, owns, mystical, thereby,
# Nearest to two: three, five, seven, six, eight, four, one, zero,
# Nearest to states: callers, chained, badges, koch, indexes, pixels, cabell, eva,
# Nearest to d: b, specificity, wenzel, e, gomorrah, iww, camino, cola,
# Nearest to from: in, paleontological, under, on, among, codeine, into, with,
# Nearest to his: their, her, its, the, s, shrine, influencing, idioms,
# Nearest to three: six, two, five, seven, four, eight, zero, nine,
# Average loss at step 22000: 3.569692
# Average loss at step 24000: 3.501788
# Average loss at step 26000: 3.583269
# Average loss at step 28000: 3.577616
# Average loss at step 30000: 3.474576
# Nearest to is: was, are, has, does, became, congestion, makes, awoke,
# Nearest to who: he, totaled, they, never, which, stumble, often, already,
# Nearest to called: dipping, hunnish, there, austral, abba, etch, illyria, bribed,
# Nearest to he: it, she, they, who, there, filler, never, lagi,
# Nearest to often: sometimes, also, commonly, generally, still, quadrant, usually, widely,
# Nearest to at: in, near, on, under, nye, after, sutcliffe, during,
# Nearest to first: last, second, third, same, oscillations, best, harriers, robbed,
# Nearest to most: more, many, longfellow, nonprofit, principles, gilgamesh, less, several,
# Nearest to they: there, he, we, you, it, cretan, she, not,
# Nearest to more: less, very, most, too, mystical, deuteronomy, chronicon, owns,
# Nearest to two: three, six, four, five, seven, eight, one, zero,
# Nearest to states: chained, indexes, eva, makes, kingdom, cistercians, koch, cabell,
# Nearest to d: b, specificity, camino, wenzel, veterinarians, v, smoother, colouring,
# Nearest to from: into, in, through, under, upstairs, codeine, among, ahaziah,
# Nearest to his: their, her, its, the, s, ericaceae, your, slovenians,
# Nearest to three: four, five, six, eight, two, seven, nine, zero,
# Average loss at step 32000: 3.525147
# Average loss at step 34000: 3.503202
# Average loss at step 36000: 3.517328
# Average loss at step 38000: 3.530895
# Average loss at step 40000: 3.432202
# Nearest to is: was, are, has, be, became, if, appears, does,
# Nearest to who: he, totaled, they, which, never, stumble, ampersand, wied,
# Nearest to called: known, used, hunnish, dipping, considered, abba, thirst, illyria,
# Nearest to he: she, it, they, who, there, filler, finally, then,
# Nearest to often: sometimes, generally, commonly, still, also, usually, widely, now,
# Nearest to at: in, on, after, booths, subtitle, under, near, qos,
# Nearest to first: second, last, third, best, only, oscillations, scoping, fourth,
# Nearest to most: more, many, some, principles, nonprofit, botswana, longfellow, ayahuasca,
# Nearest to they: we, there, you, he, it, she, cretan, who,
# Nearest to more: less, most, too, very, rather, owns, schlick, electrodes,
# Nearest to two: three, six, seven, eight, four, five, one, zero,
# Nearest to states: kingdom, indexes, nations, chained, disinformation, makes, forces, cabell,
# Nearest to d: b, camino, r, specificity, wenzel, v, veterinarians, c,
# Nearest to from: through, into, under, codeine, towards, among, in, during,
# Nearest to his: her, their, its, your, my, our, the, him,
# Nearest to three: four, seven, five, six, eight, two, nine, zero,
# Average loss at step 42000: 3.472046
# Average loss at step 44000: 3.475756
# Average loss at step 46000: 3.420474
# Average loss at step 48000: 3.065185
# Average loss at step 50000: 3.254803
# Nearest to is: was, has, became, be, although, are, discovers, appears,
# Nearest to who: and, which, totaled, they, he, she, wied, never,
# Nearest to called: considered, known, abba, see, thz, illyria, delineation, midsummer,
# Nearest to he: she, it, they, there, who, filler, but, lagi,
# Nearest to often: sometimes, generally, commonly, usually, still, also, widely, typically,
# Nearest to at: in, during, near, on, unexplored, around, under, tynwald,
# Nearest to first: last, second, third, best, same, only, next, final,
# Nearest to most: more, longfellow, less, nonprofit, gilgamesh, ayahuasca, boldness, principles,
# Nearest to they: we, there, he, you, she, cretan, it, who,
# Nearest to more: less, most, too, very, rather, owns, dramatically, smaller,
# Nearest to two: three, four, five, seven, six, one, eight, zero,
# Nearest to states: kingdom, state, nations, us, chained, disinformation, indexes, eva,
# Nearest to d: b, gomorrah, relaxing, and, tithes, ostara, cola, kitchens,
# Nearest to from: into, through, under, codeine, in, by, emitted, upstairs,
# Nearest to his: their, her, its, the, my, your, our, s,
# Nearest to three: four, five, seven, six, eight, two, nine, zero,
# Average loss at step 52000: 3.401351
# Average loss at step 54000: 3.409498
# Average loss at step 56000: 3.470829
# Average loss at step 58000: 3.454742
# Average loss at step 60000: 3.325235
# Nearest to is: was, are, if, does, has, hickok, waxes, be,
# Nearest to who: totaled, which, they, she, never, he, ampersand, stumble,
# Nearest to called: considered, named, used, illyria, known, termed, meredith, thz,
# Nearest to he: she, it, they, there, filler, later, finally, who,
# Nearest to often: sometimes, usually, generally, commonly, typically, still, now, widely,
# Nearest to at: during, in, near, unexplored, cordite, qos, under, on,
# Nearest to first: last, second, third, best, next, only, final, same,
# Nearest to most: more, many, soundboard, principles, longfellow, botswana, nonprofit, less,
# Nearest to they: we, there, he, you, she, cretan, it, these,
# Nearest to more: less, most, very, too, rather, highly, smaller, unprotected,
# Nearest to two: three, four, six, five, seven, one, eight, nine,
# Nearest to states: nations, kingdom, state, disinformation, countries, union, us, indexes,
# Nearest to d: b, cola, tithes, ostara, gomorrah, camino, whitehaven, bostonians,
# Nearest to from: through, into, towards, upstairs, nara, anteater, without, ahaziah,
# Nearest to his: her, their, its, my, your, the, our, mutual,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Average loss at step 62000: 3.430289
# Average loss at step 64000: 3.452654
# Average loss at step 66000: 3.439224
# Average loss at step 68000: 3.219438
# Average loss at step 70000: 3.366955
# Nearest to is: was, are, has, be, does, became, if, although,
# Nearest to who: which, never, he, often, she, totaled, they, borderlands,
# Nearest to called: named, considered, known, used, illyria, smoked, numan, thz,
# Nearest to he: she, it, they, there, who, filler, bankrupted, finally,
# Nearest to often: sometimes, usually, generally, commonly, now, typically, still, also,
# Nearest to at: during, in, near, unexplored, under, on, qos, after,
# Nearest to first: last, second, third, next, final, only, same, fourth,
# Nearest to most: more, less, many, some, among, botswana, ayahuasca, longfellow,
# Nearest to they: we, he, there, you, she, cretan, it, i,
# Nearest to more: less, most, very, highly, too, rather, concern, better,
# Nearest to two: three, four, eight, five, six, seven, one, nine,
# Nearest to states: nations, kingdom, state, disinformation, countries, indexes, trumbull, us,
# Nearest to d: b, gomorrah, relaxing, cola, megiddo, iww, ostara, whitehaven,
# Nearest to from: into, through, codeine, without, towards, progressives, nara, emitted,
# Nearest to his: her, their, its, the, my, your, our, audiobook,
# Nearest to three: four, seven, eight, two, five, six, nine, one,
# Average loss at step 72000: 3.314467
# Average loss at step 74000: 3.416786
# Average loss at step 76000: 3.330902
# Average loss at step 78000: 3.426467
# Average loss at step 80000: 3.417952
# Nearest to is: was, are, has, although, became, does, if, represents,
# Nearest to who: she, he, never, often, which, totaled, but, wied,
# Nearest to called: named, considered, known, used, termed, smoked, numan, illyria,
# Nearest to he: she, it, they, there, who, but, we, filler,
# Nearest to often: sometimes, usually, generally, commonly, now, typically, also, still,
# Nearest to at: during, in, under, unexplored, near, after, until, sutcliffe,
# Nearest to first: last, second, third, next, final, best, latter, only,
# Nearest to most: more, many, less, some, among, use, ayahuasca, vukovar,
# Nearest to they: we, there, he, you, she, cretan, these, it,
# Nearest to more: less, most, very, highly, rather, too, concern, better,
# Nearest to two: three, four, five, six, eight, seven, one, zero,
# Nearest to states: kingdom, nations, state, disinformation, us, chained, countries, indexes,
# Nearest to d: b, gomorrah, relaxing, ostara, c, camino, entangled, megiddo,
# Nearest to from: into, through, towards, ahaziah, codeine, in, across, via,
# Nearest to his: her, their, its, your, my, our, the, him,
# Nearest to three: four, five, two, seven, eight, six, nine, zero,
# Average loss at step 82000: 3.383669
# Average loss at step 84000: 3.346188
# Average loss at step 86000: 3.341365
# Average loss at step 88000: 3.285337
# Average loss at step 90000: 3.372339
# Nearest to is: was, has, are, became, does, although, be, if,
# Nearest to who: she, never, which, he, often, wied, already, still,
# Nearest to called: named, considered, termed, used, referred, known, numan, hunnish,
# Nearest to he: she, it, they, there, who, we, finally, filler,
# Nearest to often: sometimes, usually, generally, commonly, typically, frequently, now, still,
# Nearest to at: in, during, near, around, unexplored, on, sutcliffe, tynwald,
# Nearest to first: last, second, third, next, final, best, fourth, only,
# Nearest to most: more, many, less, some, use, all, among, botswana,
# Nearest to they: we, he, you, there, she, it, cretan, these,
# Nearest to more: less, most, very, too, rather, highly, concern, longer,
# Nearest to two: four, three, eight, six, seven, five, zero, one,
# Nearest to states: kingdom, nations, disinformation, state, us, marketed, countries, chained,
# Nearest to d: b, relaxing, gomorrah, paasikivi, cola, megiddo, bostonians, isc,
# Nearest to from: into, through, towards, in, across, emitted, of, without,
# Nearest to his: her, their, its, my, the, your, our, whose,
# Nearest to three: four, seven, six, two, five, eight, nine, zero,
# Average loss at step 92000: 3.350912
# Average loss at step 94000: 3.391666
# Average loss at step 96000: 3.395411
# Average loss at step 98000: 3.278496
# Average loss at step 100000: 3.393668
# Nearest to is: was, has, does, are, be, became, remains, becomes,
# Nearest to who: which, she, he, often, never, also, borderlands, now,
# Nearest to called: named, termed, considered, known, referred, numan, illyria, wins,
# Nearest to he: she, it, they, there, filler, who, never, we,
# Nearest to often: sometimes, usually, generally, commonly, frequently, typically, now, also,
# Nearest to at: near, during, in, unexplored, jealous, sutcliffe, within, on,
# Nearest to first: last, second, next, third, final, best, fourth, same,
# Nearest to most: more, less, many, highly, some, particularly, vukovar, among,
# Nearest to they: we, there, you, he, she, it, cretan, these,
# Nearest to more: less, most, very, too, rather, longer, highly, smaller,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to states: nations, kingdom, countries, disinformation, us, union, state, leinster,
# Nearest to d: b, c, gomorrah, relaxing, camino, ostara, megiddo, p,
# Nearest to from: through, into, across, towards, of, including, nara, ahaziah,
# Nearest to his: her, their, my, its, your, the, whose, our,
# Nearest to three: four, five, seven, two, six, eight, nine, one,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-3e7262702ef5> in <module>
#       2
#       3 tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
# ----> 4 two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
#
# NameError: name 'final_embeddings' is not defined

# %%
final_embeddings.shape
# Out:
# (50000, 128)

# %%
final_embeddings[0]
# Out:
# array([ 6.41479418e-02,  1.10419303e-01, -6.12813272e-02,  3.32483687e-02,
#        -1.46470666e-02, -4.40330468e-02, -5.76493470e-03,  8.39031022e-03,
#         6.99654175e-03, -1.08182738e-02,  3.40453684e-02, -8.26922879e-02,
#        -1.36712454e-02, -1.90067794e-02, -1.30768856e-02,  1.00141488e-01,
#        -9.62775424e-02, -4.76030856e-02, -5.03153279e-02, -2.08609477e-01,
#         8.71005654e-02, -2.92209927e-02, -1.56812351e-02, -1.20961934e-01,
#         8.78204256e-02, -8.61857757e-02, -3.92275676e-02,  1.30093172e-01,
#         1.69911787e-01, -2.47979444e-02, -1.81150585e-02,  1.25802457e-01,
#        -1.98328178e-02, -6.79228455e-02, -1.22642703e-01, -1.71153113e-01,
#        -5.76608554e-02,  4.07302417e-02, -2.62689944e-02, -7.31999725e-02,
#        -6.60718307e-02, -4.87573631e-02,  1.53700352e-01, -4.97955270e-02,
#        -1.06046177e-01,  1.58647254e-01, -1.43818781e-01,  9.84547287e-02,
#        -5.21711968e-02,  5.75020276e-02,  8.80862921e-02,  1.50096923e-01,
#        -4.68390808e-02,  3.05207763e-02, -1.61508098e-01,  8.64906982e-02,
#        -1.21414103e-01,  5.61462529e-02,  2.18103856e-01, -5.28206378e-02,
#        -1.32842392e-01, -2.31901580e-03, -1.27309533e-02, -7.28827789e-02,
#         2.13333089e-02,  1.69996470e-01,  1.33370191e-01,  9.03892070e-02,
#         1.66569576e-01, -1.23733729e-01,  4.09998111e-02,  2.02650875e-02,
#         3.70009243e-02,  7.70071447e-02, -5.38666360e-03, -2.14172564e-02,
#         1.82190895e-01,  3.23094800e-02, -5.86867295e-02, -7.63577176e-03,
#        -1.89299062e-02,  7.25993663e-02,  9.17226076e-02, -9.25637688e-03,
#         6.98386878e-03,  3.50271724e-02,  4.47577098e-04,  1.90620665e-02,
#         1.22777574e-01,  1.22100882e-01,  4.36518863e-02, -1.46385208e-01,
#         6.07189164e-03,  1.77993596e-01,  3.21428403e-02,  1.40937686e-01,
#         7.70400232e-03, -3.12293805e-02,  8.91765058e-02,  5.76259494e-02,
#         7.16813207e-02,  6.89232722e-02,  1.04542669e-04, -1.95014980e-02,
#         6.01925887e-02, -1.04633085e-01, -7.33679980e-02,  1.12071550e-02,
#         1.12092274e-03,  3.22670937e-02, -1.35903597e-01,  7.46200457e-02,
#        -6.86938688e-02, -2.76810559e-03, -8.33351165e-02, -2.29846805e-01,
#        -9.28431675e-02,  1.62660122e-01, -3.09388246e-02,  1.72217712e-02,
#        -2.16026939e-02,  1.97735671e-02,  1.25888944e-01,  5.49724139e-03,
#         4.18066196e-02,  5.77392466e-02, -1.12220511e-01,  4.95387726e-02],
#       dtype=float32)

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ##### I dont think that above is CBOW because it does skip of at least 1 word.

# %%
len(words)
# Out:
# 17005207

# %%
data= []
for i in range(0,len(words),20):
    data.append(words[i:i+20])
    
len(data)
# Out:
# 850261

# %%
data[0]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %%
import gensim 
from gensim.models import Word2Vec 

# Create CBOW model 
model1 = gensim.models.Word2Vec(data, min_count = 1, size = 128, window = 5)

# %%
model1.wv.vectors.shape
# Out:
# (253854, 128)

# %%
model1.wv.vectors[0]
# Out:
# array([-0.7387961 , -0.16174899, -0.47900054, -0.26267672, -1.1441548 ,
#         0.27423418,  0.49561056, -0.6035397 ,  0.29838967, -1.9728812 ,
#        -0.7270793 ,  0.82056814, -1.2138765 ,  0.2929528 ,  0.7136204 ,
#        -1.0125729 , -1.474087  , -1.3455206 ,  0.8431317 , -0.14065862,
#        -1.6258793 , -0.6205802 ,  0.16875677,  0.39909884, -0.01609624,
#        -1.0692201 , -1.5094674 ,  0.7620742 ,  2.1068404 ,  0.5711187 ,
#         0.10708958, -1.1874994 , -1.599075  , -0.94379747,  0.33297583,
#        -0.02089367, -0.16445123,  0.7841332 , -1.2941564 ,  0.7755587 ,
#         1.0647876 , -0.64686275,  0.26347575, -0.81185097, -0.11082847,
#         0.26000136, -0.29943138,  0.9590771 ,  0.6411499 , -0.333527  ,
#        -1.1119418 , -1.1915725 , -0.9174256 ,  1.8612337 , -0.84016246,
#        -0.1917015 , -1.2815431 , -0.12453543,  0.29665652, -0.44995928,
#         1.0761582 ,  0.10788696,  0.49037412, -0.83915085, -0.19274972,
#        -0.9701664 , -0.43334916,  0.8188621 , -1.3847361 ,  0.39664897,
#        -0.540065  , -1.4215614 ,  0.80263025, -0.74383295,  0.07803454,
#        -1.7818153 , -0.44049838, -1.6907377 ,  0.26437998,  0.36834922,
#        -1.2587913 ,  1.8591136 ,  2.2057593 , -0.41731134, -2.0372226 ,
#         1.6929768 ,  1.7852077 ,  0.267219  , -1.5765252 , -2.5903883 ,
#        -0.97279924, -1.9628906 , -1.8736458 ,  1.234193  , -0.5148864 ,
#         0.6895214 , -1.3329419 , -0.52785766, -0.03943342,  0.11201207,
#         0.2408138 ,  0.49070176,  0.10729618, -0.22510085,  1.2496036 ,
#         1.0379679 ,  1.7074764 ,  0.7043133 ,  0.05161554, -0.3914693 ,
#         0.66915536,  0.26977426,  0.24865921,  1.3888462 ,  0.90061057,
#        -0.81334406,  1.2439877 , -0.13318253, -0.33682507,  1.0142502 ,
#        -1.3705896 ,  0.11224579, -0.42344657, -0.14179336, -0.60762346,
#         0.6843065 ,  1.5866904 , -0.5048979 ], dtype=float32)

# %%
len(model1.wv.vocab)
# Out:
# 253854

# %%
type(model1.wv.vocab['the'])
# Out:
# gensim.models.keyedvectors.Vocab

# %%
model1.wv.vocab.keys()
# Out:
# dict_keys(['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'english', 'revolution', 'and', 'sans', 'culottes', 'french', 'whilst', 'is', 'still', 'in', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'violent', 'means', 'destroy', 'organization', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'word', 'derived', 'from', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'political', 'philosophy', 'belief', 'rulers', 'are', 'unnecessary', 'should', 'be', 'abolished', 'although', 'there', 'differing', 'interpretations', 'what', 'this', 'refers', 'related', 'social', 'movements', 'advocate', 'elimination', 'authoritarian', 'institutions', 'particularly', 'state', 'anarchy', 'most', 'use', 'does', 'not', 'imply', 'chaos', 'nihilism', 'or', 'anomie', 'but', 'rather', 'harmonious', 'anti', 'place', 'regarded', 'structures', 'coercive', 'economic', 'relations', 'based', 'upon', 'voluntary', 'association', 'autonomous', 'individuals', 'mutual', 'aid', 'governance', 'while', 'easily', 'offer', 'visions', 'they', 'believe', 'truly', 'free', 'however', 'ideas', 'about', 'how', 'an', 'anarchist', 'might', 'work', 'vary', 'considerably', 'especially', 'with', 'respect', 'economics', 'disagreement', 'brought', 'origins', 'predecessors', 'kropotkin', 'others', 'argue', 'before', 'recorded', 'history', 'human', 'was', 'organized', 'on', 'principles', 'anthropologists', 'follow', 'engels', 'believing', 'hunter', 'gatherer', 'bands', 'were', 'egalitarian', 'lacked', 'division', 'labour', 'accumulated', 'wealth', 'decreed', 'law', 'had', 'equal', 'access', 'resources', 'william', 'godwin', 'organisation', 'rothbard', 'find', 'attitudes', 'taoism', 'ancient', 'china', 'found', 'similar', 'stoic', 'zeno', 'citium', 'according', 'repudiated', 'omnipotence', 'its', 'intervention', 'regimentation', 'proclaimed', 'sovereignty', 'moral', 'individual', 'anabaptists', 'one', 'six', 'th', 'century', 'europe', 'sometimes', 'considered', 'religious', 'forerunners', 'modern', 'bertrand', 'russell', 'his', 'western', 'writes', 'all', 'since', 'held', 'good', 'man', 'will', 'guided', 'at', 'every', 'moment', 'holy', 'spirit', 'premise', 'arrive', 'communism', 'true', 'levellers', 'communistic', 'movement', 'during', 'time', 'civil', 'war', 'some', 'era', 'mean', 'something', 'other', 'than', 'louis', 'armand', 'baron', 'de', 'lahontan', 'nouveaux', 'voyages', 'dans', 'l', 'am', 'rique', 'septentrionale', 'seven', 'zero', 'three', 'where', 'he', 'described', 'indigenous', 'american', 'which', 'no', 'laws', 'prisons', 'priests', 'private', 'property', 'being', 'libertarian', 'leader', 'indian', 'repeatedly', 'stated', 'so', 'ancestors', 'nine', 'thick', 'published', 'enquiry', 'concerning', 'justice', 'did', 'many', 'later', 'have', 'book', 'major', 'text', 'founder', 'philosophical', 'point', 'yet', 'existed', 'anarchiste', 'known', 'mainly', 'insult', 'hurled', 'bourgeois', 'girondins', 'more', 'radical', 'elements', 'labelled', 'pierre', 'joseph', 'proudhon', 'commonly', 'wasn', 't', 'until', 'eight', 'four', 'adopted', 'description', 'for', 'reason', 'claim', 'theory', 'answers', 'famous', 'accusation', 'theft', 'opposed', 'institution', 'propri', 'owners', 'complete', 'rights', 'their', 'wish', 'such', 'exploiting', 'workers', 'profit', 'supported', 'called', 'possession', 'can', 'limited', 'capital', 'goods', 'accordance', 'equality', 's', 'vision', 'mutualism', 'mutuellisme', 'involved', 'exchange', 'economy', 'groups', 'could', 'trade', 'products', 'labor', 'using', 'notes', 'represented', 'amount', 'production', 'would', 'ensure', 'freely', 'join', 'together', 'co', 'operative', 'workshops', 'interest', 'bank', 'set', 'provide', 'everyone', 'influential', 'within', 'followers', 'active', 'france', 'complex', 'developed', 'number', 'works', 'over', 'lifetime' ...

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(model1.wv.vectors[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

# %%
plot(two_d_embeddings, list(model1.wv.vocab.keys())[1:num_points])
